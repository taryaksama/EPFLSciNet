# %% [markdown]
# # main.ipynb

# %% [markdown]
# Rationale:
# EPFL faculty members participate in numerous collaborative projects wether with other faculty members from Switzerland and abroad and/or companies. These data are precious to map this collaborative network and leverage future groundbraking projects.
#
# Objectives:
# 1. Concatenate various project data sources (i. SNF, ii. Horizon Europe)
# 2. Map the collaborative network
# 3. Describe the network (quantify KOL, find clusters, ...)
# 4. Find applicability to project Launch (complementary domains, best team, ...)

# %% [markdown]
# # Initialisation

# %%
import os
import json
import re
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

from src import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Set path of the folder containing dataset
dataset_FolderPath = Path.cwd() / 'data'

# %% [markdown]
# # SNF Database

# %% [markdown]
# ## Load Persons

# %%
# Load all people in SNF database
Person_filename = 'Person.csv'
Person_columns_to_load = [
    'Surname', 
    'FirstName', 
    'ResearchInstitution', 
    'InstituteCountry', 
    'PersonNumber', 
    'ResponsibleApplicantGrantNumber', 
    'CoApplicantGrantNumber', 
    'ProjectPartnerGrantNumber'
    ]

Person_df = pd.read_csv(dataset_FolderPath / 'SNF' / Person_filename, usecols=Person_columns_to_load, sep=';')
Person_df
# Out:
#           Surname      FirstName          InstituteCountry  \
# 0       Schmocker           Beat               Switzerland
# 1          Perrin        Nicolas               Switzerland
# 2           Jäger          Peter                       NaN
# 3            Beck            Jan               Switzerland
# 4        Wittmann          Frank                       NaN
# ...           ...            ...                       ...
# 141383   Szlajfer         Feliks                       NaN
# 141384      Kosek            Eva                    Sweden
# 141385      Nunez         Rafael  United States of America
# 141386  Fersztand  Anna Raphaela   Switzerland;Switzerland
# 141387     Widmer         Gaelle                       NaN
#
#                                       ResearchInstitution  PersonNumber  \
# 0       Non-profit organisations (libraries, museums, ...        533578
# 1                             University of Lausanne – LA         44113
# 2                                                     NaN        530171
# 3                                University of Basel – BS        541633
# 4                                                     NaN        139096
# ...                                                   ...           ...
# 141383                                                NaN         30076
# 141384                                                NaN        572943
# 141385                                                NaN         59355
# 141386  University of Zurich – ZH;University of Zurich...        809705
# 141387                                                NaN        131350
#
#                           ResponsibleApplicantGrantNumber  \
# 0                                                     NaN
# 1       166323;147625;147091;129894;112511;108100;1003...
# 2                                                     NaN
# 3                                    151055;135899;119879
# 4                                            119336;69255
# ...                                                   ...
# 141383                                              29427
# 141384                                                NaN
# 141385                                              33279
# 141386                                             222552
# 141387                                                NaN
#
#        CoApplicantGrantNumber ProjectPartnerGrantNumber
# 0                         NaN                       NaN
# 1          142108;41191;34592                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 141383                    NaN                       NaN
# 141384                    NaN                    182686
# 141385                    NaN                       NaN
# 141386                    NaN                       NaN
# 141387                    NaN                       NaN
#
# [141388 rows x 8 columns]

# %%
# Filter by EPFL members that worked in collab projects

EPFL_faculty_collab = Person_df[
    Person_df['ResearchInstitution'].str.contains('EPF Lausanne – EPFL', na=False) &
    (Person_df[['ResponsibleApplicantGrantNumber', 'CoApplicantGrantNumber', 'ProjectPartnerGrantNumber']].notna().sum(axis=1) >= 2)
    ]
EPFL_faculty_collab
# Out:
#                 Surname         FirstName  \
# 720             Weinand              Yves
# 1207            Neronov            Andrii
# 1281              Knott            Graham
# 1400    Jolles-Haeberli          Brigitte
# 1779            Boillat              Eric
# ...                 ...               ...
# 140919            Meyer           Thierry
# 140943         Pimienta         Lucas Xan
# 141058           Hughes             Josie
# 141197          Pralong  William-François
# 141234      Pu Faltings             Pearl
#
#                                          InstituteCountry  \
# 720                                           Switzerland
# 1207                       France;Switzerland;Switzerland
# 1281                                          Switzerland
# 1400    Switzerland;Switzerland;Switzerland;Switzerlan...
# 1779                                          Switzerland
# ...                                                   ...
# 140919                                        Switzerland
# 140943                                        Switzerland
# 141058                            Switzerland;Switzerland
# 141197                Switzerland;Switzerland;Switzerland
# 141234                                        Switzerland
#
#                                       ResearchInstitution  PersonNumber  \
# 720                                   EPF Lausanne – EPFL        515936
# 1207    Institution abroad – IACH;EPF Lausanne – EPFL;...        137689
# 1281                                  EPF Lausanne – EPFL         42271
# 1400    University of Lausanne – LA;University of Laus...        122322
# 1779                                  EPF Lausanne – EPFL         42669
# ...                                                   ...           ...
# 140919                                EPF Lausanne – EPFL         46282
# 140943                                EPF Lausanne – EPFL        711504
# 141058            EPF Lausanne – EPFL;EPF Lausanne – EPFL        781436
# 141197  University of Lausanne – LA;EPF Lausanne – EPF...         36406
# 141234                                EPF Lausanne – EPFL         57735
#
#                           ResponsibleApplicantGrantNumber  \
# 720     189596;137884;137704;126802;120037;112103;1037...
# 1207                                        144923;123426
# 1281                                        170082;112335
# 1400                                        166433;104752
# 1779                           155966;132115;109418;68042
# ...                                                   ...
# 140919           140209;129516;115900;109051;101477;61403
# 140943                                             190789
# 141058                             10001574;226507;221366
# 141197                                              40511
# 141234  184602;138054;119955;116454;111888;103490;1003...
#
#                           CoApplicantGrantNumber    ProjectPartnerGrantNumber
# 720                  205604;182887;141853;127467                          NaN
# 1207          219937;158533;154221;135263;111020                165932;165902
# 1281          213528;170955;170767;154453;130470  219656;212233;177237;173125
# 1400    184851;137940;120422;120136;105880;64951                          NaN
# 1779                                 66763;54156                          NaN
# ...                                          ...                          ...
# 140919                               54480;36611                          NaN
# 140943                                       NaN                       212730
# 141058                                       NaN                       212101
# 141197             65404;64149;58682;58663;32376                          NaN
# 141234                   66915;61493;54537;52439                          NaN
#
# [744 rows x 8 columns]

# %% [markdown]
# ### Build network of PIs linked by projects

# %%
import networkx as nx
from pyvis.network import Network
from itertools import combinations

# %%
# Pre-processing of data
df = EPFL_faculty_collab.copy()
df = df.explode('ResponsibleApplicantGrantNumber').reset_index(drop=True)

df['CoApplicantGrantNumber'] = df['CoApplicantGrantNumber'].str.split(';')
df = df.explode('CoApplicantGrantNumber').reset_index(drop=True)

df['ProjectPartnerGrantNumber'] = df['ProjectPartnerGrantNumber'].str.split(';')
df = df.explode('ProjectPartnerGrantNumber').reset_index(drop=True)

df

###
melted_df = pd.melt(df, id_vars=['Surname', 'FirstName', 'PersonNumber'], value_vars=['ResponsibleApplicantGrantNumber', 'CoApplicantGrantNumber', 'ProjectPartnerGrantNumber'], var_name='ApplicantType', value_name='ProjectID')
melted_df = melted_df.dropna().reset_index(drop=True)
melted_df = melted_df.rename(columns={'PersonNumber': 'PersonID'})

network_data = melted_df

# %%
### Using pyvis (DEPRECATED)

# Create a graph
G = nx.Graph()

# Add edges based on the DataFrame
for _, row in network_data.iterrows():
    G.add_node(row['PersonID'], label=f"Person {row['PersonID']}")
    G.add_node(row['ProjectID'], label=f"Project {row['ProjectID']}")
    G.add_edge(row['PersonID'], row['ProjectID'])

# Create a PyVis network
net = Network(notebook=True, height="750px", width="100%")

# Load the NetworkX graph into PyVis
net.from_nx(G)

# Show the interactive network
net.show("example.html", notebook=False)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# example.html

# %% [markdown]
# ## Load projects

# %%
# Load all projects in SNF database
Project_filename = 'GrantWithAbstracts.csv'
Project_columns_to_load = [
    'GrantNumber',
    'Title',
    'FundingInstrumentPublished',
    'EffectiveGrantStartDate',
    'EffectiveGrantEndDate',
    'AmountGrantedAllSets',
    'Abstract',
    'State'
]

Project_df = pd.read_csv(dataset_FolderPath / 'SNF' / Project_filename, usecols=Project_columns_to_load, sep=';')
Project_df
# Out:
#        GrantNumber                                              Title  \
# 0           172205                       IceCube Event Reconstruction
# 1            58440      Des images pour agir. Le visuel en urbanisme.
# 2             4578  Synthese und Biosynthese von 'Betalain-Merocya...
# 3           106888  Les manuscrits romains de musique pour le clav...
# 4           152511  Ramsey spectroscopy in Rb vapour cells and app...
# ...            ...                                                ...
# 88300         6025  Aspects cellulaires et sub-cellulaires de la r...
# 88301       139309  Medical end-of-life decisions: prevalence and ...
# 88302       194873  Encountering, occupying and exceeding categori...
# 88303        28493  Etudes de la flore et de la végétation du Chac...
# 88304       140571                Leadership Across Economic Contexts
#
#                     FundingInstrumentPublished EffectiveGrantStartDate  \
# 0                       Early Postdoc.Mobility    2017-01-01T00:00:00Z
# 1                           Publication grants    2000-03-07T00:00:00Z
# 2                              Project funding    1985-07-01T00:00:00Z
# 3      Fellowships for prospective researchers    2004-12-01T00:00:00Z
# 4                                       SCOPES    2014-06-01T00:00:00Z
# ...                                        ...                     ...
# 88300                          Project funding    1976-10-01T00:00:00Z
# 88301                       NRP 67 End of Life    2013-03-01T00:00:00Z
# 88302                             Doc.Mobility    2021-10-01T00:00:00Z
# 88303                          Project funding    1990-10-01T00:00:00Z
# 88304                          Project funding    2012-09-01T00:00:00Z
#
#       EffectiveGrantEndDate  AmountGrantedAllSets  \
# 0      2018-06-30T00:00:00Z               74145.0
# 1      2000-04-06T00:00:00Z               12000.0
# 2      1987-09-30T00:00:00Z              174480.0
# 3      2005-07-31T00:00:00Z               25470.0
# 4      2018-10-31T00:00:00Z              104599.0
# ...                     ...                   ...
# 88300  1978-09-30T00:00:00Z              584618.0
# 88301  2018-01-31T00:00:00Z              640027.0
# 88302  2022-09-30T00:00:00Z               51200.0
# 88303  1993-09-30T00:00:00Z              335662.0
# 88304  2014-08-31T00:00:00Z              335702.0
#
#                                                 Abstract      State
# 0      The IceCube observatory at the South Pole is a...  Completed
# 1                                                    NaN  Completed
# 2                                                    NaN  Completed
# 3                                                    NaN  Completed
# 4      In this project the teams of Prof. Gaetano Mil...  Completed
# ...                                                  ...        ...
# 88300                                                NaN  Completed
# 88301  BackgroundEthical issues in end-of-life decisi...  Completed
# 88302  My Ph.D. dissertation investigates the Latin A...  Completed
# 88303                                                NaN  Completed
# 88304  Leadership is a potential solution to many imp...  Completed
#
# [88305 rows x 8 columns]
